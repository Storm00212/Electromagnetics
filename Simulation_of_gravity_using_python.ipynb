# %% [markdown]
# <a href="https://colab.research.google.com/github/Storm00212/Electromagnetics/blob/main/Simulation_of_gravity_using_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
# Physical constants
c = 1.0          # speed of light (scaled)   I normalized it but you can use the actual speed tho
omega = 2*np.pi # angular frequency

# %%
# 3D spatial grid
grid_size = 40
x = np.linspace(-5, 5, grid_size)
y = np.linspace(-5, 5, grid_size)
z = np.linspace(-5, 5, grid_size)
X, Y, Z = np.meshgrid(x, y, z)

# %%
# Radial distance (avoid division by zero)
r = np.sqrt(X**2 + Y**2 + Z**2) + 1e-6

# %%
# Time parameters
dt = 0.1
t_vals = np.linspace(0, 10, 100)
